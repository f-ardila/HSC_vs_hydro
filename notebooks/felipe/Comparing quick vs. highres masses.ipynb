# %%
import sys
sys.path.append('/Users/fardila/Documents/GitHub/HSC_vs_hydro/')
from functions import *
# Out:
# Created TAP+ (v1.0) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: False
# 	Port: 80
# 	SSL Port: 443
#
#
#       +------------------------------------------------------------+
#       |             Space Telescope Tables Package                 |
#       |                  TABLES Version 3.18.3                     |
#       |                                                            |
#       |   Space Telescope Science Institute, Baltimore, Maryland   |
#       |   Copyright (C) 2014 Association of Universities for       |
#       |            Research in Astronomy, Inc.(AURA)               |
#       |       See stsdas$copyright.stsdas for terms of use.        |
#       |         For help, send e-mail to help@stsci.edu            |
#       +------------------------------------------------------------+
# tables/:
#  fitsio/        tbplot/         tobsolete/      ttools/
#
#
#       +------------------------------------------------------------+
# ...

# %% [markdown]
# # get masses from merged isos?

# %%
#certain masses will depend on maps directly
# iso = load_pkl('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Data/TNG/TNG_isos_merged.pkl')
# masses_merged = get_masses(iso, sim_file, sim_name, resolution, rs, gal_n=0):

# %% [markdown]
# set up framework for comparisons first from other notebooks

# %% [markdown]
# # TNG

# %%
tng_masses_quick = load_pkl('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Data/TNG/TNG_masses_quick.pkl')
tng_masses_highres = load_pkl('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Data/TNG/TNG_masses_highres.pkl')

# %%
fig=plt.figure(figsize=[15,25])
ax1=plt.subplot(511)
ax2=plt.subplot(512)
ax3=plt.subplot(513)
ax4=plt.subplot(514)
ax5=plt.subplot(515)


ax1.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_cat'] - tng_masses_quick['m_post'], c=u'#1f77b4',
            label='quick: large physical size, lower resolution')
ax1.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat'] - tng_masses_highres['m_post'], c='r',
           label= 'highres', alpha=0.5)
# ax1.plot(xs, tng_diff_cat_post_line(xs), c=u'#1f77b4')
ax1.axhline(0,c="k",linewidth=2,linestyle='--')
# ax1.text(12, 0.05,'linear params: ' + str(tng_diff_cat_post_params), fontsize=15)
ax1.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{post}}$', fontsize=30)

ax2.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_cat'] - tng_masses_quick['m_post_icl'], c=u'#1f77b4')
ax2.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat'] - tng_masses_highres['m_post_icl'], c='r', 
            alpha=0.5)
# ax2.plot(xs, tng_diff_cat_post_icl_line(xs), c=u'#1f77b4')
ax2.axhline(0,c="k",linewidth=2,linestyle='--')
# ax2.text(12, 0.05,'linear params: ' + str(tng_diff_cat_post_icl_params), fontsize=15)
ax2.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{post, diffuse}}$ ', fontsize=30)

ax3.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_cat'] - tng_masses_quick['m_1d_100'], c=u'#1f77b4')
ax3.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat'] - tng_masses_highres['m_1d_100'], c='r', 
            alpha=0.5)
# ax3.plot(xs, tng_diff_cat_1d100_line(xs), c=u'#1f77b4')
ax3.axhline(0, c="k",linewidth=2, linestyle='--')
# ax3.text(12, 0.05,'linear params: ' + str(tng_diff_cat_1d100_params), fontsize=15)
ax3.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{1d, 100}}$ ', fontsize=30)

ax4.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_2d_100'] - tng_masses_quick['m_1d_100'], c=u'#1f77b4')
ax4.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_2d_100'] - tng_masses_highres['m_1d_100'], c='r', 
            alpha=0.5)
# ax4.plot(xs, tng_diff_2d_1d_30_line(xs), c=u'#1f77b4')
ax4.axhline(0,c="k",linewidth=2,linestyle='--')
# ax4.text(12, 0.05,'linear params: ' + str(tng_diff_2d_1d_30_params), fontsize=15)
ax4.set_ylabel(r'$M_{\star}^{\mathrm{2d, 100}}$ - $M_{\star}^{\mathrm{1d, 100}}$ ', fontsize=30)

ax5.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_cat'] - tng_masses_quick['extrapolated_m_300'], c=u'#1f77b4')
ax5.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat'] - tng_masses_highres['extrapolated_m_300'], c='r', 
            alpha=0.5)
# ax5.plot(xs, tng_diff_cat_1dextrap_line(xs), c=u'#1f77b4')
ax5.axhline(0,c="k",linewidth=2,linestyle='--')
# ax5.text(12, 0.05,'linear params: ' + str(tng_diff_cat_1dextrap_params), fontsize=15)
ax5.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{extrap, 300}}$ ', fontsize=30)


ax1.legend(fontsize=20)

ax5.set_xlabel('$M_{\star}^{\mathrm{cat}}$', fontsize=40)
ax1.set_title('TNG', fontsize=45)
#plt.tight_layout()

for ax in [ax1,ax2,ax3,ax4,ax5]:
    ax.set_ylim([-0.25,0.25])
    
# fig.savefig('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Plots/mass_differences_TNG.pdf',
#             dpi=100, format='pdf', bbox_inches='tight')

# %%
fig= plt.figure()
ax4=plt.subplot()

ax4.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_cat'] - tng_masses_quick['m_2d_100'], c=u'#1f77b4')
ax4.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat'] - tng_masses_highres['m_2d_100'], c='r', 
            alpha=0.5)
# ax4.plot(xs, tng_diff_2d_1d_30_line(xs), c=u'#1f77b4')
ax4.axhline(0,c="k",linewidth=2,linestyle='--')
# ax4.text(12, 0.05,'linear params: ' + str(tng_diff_2d_1d_30_params), fontsize=15)
ax4.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{2d, 100}}$ ', fontsize=30)
# Out:
# Text(0,0.5,'$M_{\\star}^{\\mathrm{cat}}$ - $M_{\\star}^{\\mathrm{2d, 100}}$ ')

# %%
fig= plt.figure()
ax4=plt.subplot()
ax4.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_2d_10']-tng_masses_highres['m_2d_10'], 
            alpha=0.5, label='10 kpc')
ax4.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_2d_30']-tng_masses_highres['m_2d_30'], 
            alpha=0.5, label='30 kpc')
ax4.scatter(tng_masses_highres['m_cat'], tng_masses_quick['m_2d_100']-tng_masses_highres['m_2d_100'], 
            alpha=0.5, label='100 kpc')
# ax4.plot(xs, tng_diff_2d_1d_30_line(xs), c=u'#1f77b4')
ax4.axhline(0,c="k",linewidth=2,linestyle='--')
# ax4.text(12, 0.05,'linear params: ' + str(tng_diff_2d_1d_30_params), fontsize=15)
ax4.set_ylabel(r'$M_{\star, quick}^{\mathrm{2d}}$ - $M_{\star, highres}^{\mathrm{2d}}$ ', fontsize=30)
ax4.set_xlabel(r'$M_{\star}^{cat} $ ', fontsize=30)

plt.legend()

plt.show()

# %%
fig= plt.figure()
ax4=plt.subplot()

ax4.scatter(tng_masses_highres['m_cat'], tng_masses_quick['m_2d_100']-tng_masses_highres['m_2d_100'], 
            alpha=0.5, label='100 kpc')
# ax4.plot(xs, tng_diff_2d_1d_30_line(xs), c=u'#1f77b4')
ax4.axhline(0,c="k",linewidth=2,linestyle='--')
# ax4.text(12, 0.05,'linear params: ' + str(tng_diff_2d_1d_30_params), fontsize=15)
ax4.set_ylabel(r'$M_{\star, quick}^{\mathrm{2d}}$ - $M_{\star, highres}^{\mathrm{2d}}$ ', fontsize=30)
ax4.set_xlabel(r'$M_{\star}^{cat} $ ', fontsize=30)

plt.legend()

plt.show()

# %%
fig= plt.figure(figsize=[15,15])
ax3=plt.subplot(211)
ax4=plt.subplot(212)
ax3.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_cat']-tng_masses_quick['m_1d_10'], 
            alpha=0.5, label='10 kpc')
ax3.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_cat']-tng_masses_quick['m_1d_30'], 
            alpha=0.5, label='30 kpc')
ax3.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_cat']-tng_masses_quick['m_1d_100'], 
            alpha=0.5, label='100 kpc')

ax4.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat']-tng_masses_highres['m_1d_10'], 
            alpha=0.5, label='10 kpc')
ax4.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat']-tng_masses_highres['m_1d_30'], 
            alpha=0.5, label='30 kpc')
ax4.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat']-tng_masses_highres['m_1d_100'], 
            alpha=0.5, label='100 kpc')

# ax3.plot(xs, tng_diff_cat_1d100_line(xs), c=u'#1f77b4')
ax3.axhline(0, c="k",linewidth=2, linestyle='--')
ax4.axhline(0, c="k",linewidth=2, linestyle='--')

ax3.legend()

ax3.set_ylim([-0.2,0.8])
ax4.set_ylim([-0.2,0.8])
# ax3.text(12, 0.05,'linear params: ' + str(tng_diff_cat_1d100_params), fontsize=15)
ax3.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{1d, quick}}$ ', fontsize=30)
ax4.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{1d, highres}}$ ', fontsize=30)
ax4.set_xlabel(r'$M_{\star}^{\mathrm{cat}}$ ', fontsize=30)
# Out:
# Text(0.5,0,'$M_{\\star}^{\\mathrm{cat}}$ ')

# %%
fig= plt.figure()
ax4=plt.subplot()
ax4.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_1d_10']-tng_masses_highres['m_1d_10'], 
            alpha=0.5, label='10 kpc')
ax4.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_1d_30']-tng_masses_highres['m_1d_30'], 
            alpha=0.5, label='30 kpc')
ax4.scatter(tng_masses_highres['m_cat'], tng_masses_quick['m_1d_100']-tng_masses_highres['m_1d_100'], 
            alpha=0.5, label='100 kpc')
# ax4.plot(xs, tng_diff_2d_1d_30_line(xs), c=u'#1f77b4')
ax4.axhline(0,c="k",linewidth=2,linestyle='--')
# ax4.text(12, 0.05,'linear params: ' + str(tng_diff_2d_1d_30_params), fontsize=15)
ax4.set_ylabel(r'$M_{\star, quick}^{\mathrm{1d}}$ - $M_{\star, highres}^{\mathrm{1d}}$ ', fontsize=30)
ax4.set_xlabel(r'$M_{\star}^{cat} $ ', fontsize=30)

plt.legend()

plt.show()

# %% [markdown]
# 9/14/18:
#
# compare masses highres vs. quick - there seems to be a difference (red vs. blue)
#
# figure out discrepancy between 2d and 1d mass
#
# confused about why M_1d_100 does much worse in highres than quick...compare profiles

# %% [markdown]
# ## plot profiles

# %%
tng_isos_quick = load_pkl('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Data/TNG/TNG_isos_quick.pkl')
tng_isos_highres = load_pkl('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Data/TNG/TNG_isos_highres.pkl')

# %%
cat_masses = tng_masses_quick['m_cat']

# %%
# fig, (ax1, ax2, ax3) = plt.subplots(1,3, sharey=False, figsize=(10*3, 10))
# fig.subplots_adjust(left=0.22, right=0.995, bottom=0.14, top=0.94, wspace=0.00, hspace=0.00)
fig=plt.figure(figsize=(10*6, 10))
gs1 = gridspec.GridSpec(1, 3)
gs1.update(left=0.05, right=0.48, wspace=0.0)
ax1 = plt.subplot(gs1[0, 0])
ax2 = plt.subplot(gs1[0, 1])
gs2 = gridspec.GridSpec(1, 3)
gs2.update(left=0.05, right=0.48, wspace=0.0)
ax3 = plt.subplot(gs2[0, -1])

#mass range 1
tng_isos1=[]
ngals1=0

#mass range 2
tng_isos2=[]
ngals2=0

#mass range 3
tng_isos3=[]
ngals3=0

######################################################################################################################
# plot
######################################################################################################################
#hsc
# ax1.plot(RSMA_COMMON, hscMedProf_116_118, linestyle='--', linewidth=4.0, c='k',
#          alpha=1, zorder=8, label='HSC')
# ax2.plot(RSMA_COMMON, hscMedProf_118_120, linestyle='--', linewidth=4.0, c='k',
#          alpha=1, zorder=8, label='HSC')
  
mass_bins=np.linspace(11.2,12.5,4)

#mass range 1
tng_isos1=[]
ngals1=0

#mass range 2
tng_isos2=[]
ngals2=0

#mass range 3
tng_isos3=[]
ngals3=0
for mass, iso in zip(cat_masses, tng_isos_quick): 
    
    if (mass<mass_bins[0]) or (mass>mass_bins[-1]):
        continue

    elif (mass>=mass_bins[0]) and (mass<mass_bins[1]):
        ngals1+=1

        tng_isos1.append(iso)

        ax1.plot((iso['sma_kpc']) ** 0.25,
             np.log10(iso['intens_kpc'])+ np.log10(0.7 ** 2.0) , linewidth=0.5, c=u'#1f77b4', alpha=0.2, 
                 label='_nolegend_', zorder=1)
                 #label='tng Galaxy '+str(i)+': $M_{\star} = $'+str(round(m_star,1)))
            
        
    elif (mass>=mass_bins[1]) and (mass<mass_bins[2]):
        ngals2+=1
        
        tng_isos2.append(iso)

        ax2.plot((iso['sma_kpc']) ** 0.25,
             np.log10(iso['intens_kpc'] )+ np.log10(0.7 ** 2.0), linewidth=0.5, c=u'#1f77b4', alpha=0.4, 
                 label='_nolegend_')
                 #label='tng Galaxy '+str(i)+': $M_{\star} = $'+str(round(m_star,1)))
    
    elif (mass>=mass_bins[2]) and (mass<mass_bins[3]) :
        if (np.interp(6, iso['sma_kpc'], np.log10(iso['intens_kpc'])+ np.log10(0.7 ** 2.0)) > 8):#remove mergers:
            ngals3+=1

            tng_isos3.append(iso)

            ax3.plot((iso['sma_kpc']) ** 0.25,
                 np.log10(iso['intens_kpc'])+ np.log10(0.7 ** 2.0), linewidth=0.5, c=u'#1f77b4', alpha=0.6, 
                     label='_nolegend_')
                     #label='tng Galaxy '+str(i)+': $M_{\star} = $'+str(round(m_star,1)))


        
## median profiles for tng
median_sma1, median_mu1 = get_median_profile(tng_isos1, pixel_scale = 0, quantity='intens_kpc')
median_sma2, median_mu2 = get_median_profile(tng_isos2, pixel_scale = 0, quantity='intens_kpc')
median_sma3, median_mu3 = get_median_profile(tng_isos3, pixel_scale = 0, quantity='intens_kpc')

ax1.plot(median_sma1, median_mu1+ np.log10(0.7 ** 2.0), linewidth=7.0, c=u'#1f77b4', alpha=1, label='Quick', zorder=5)
ax2.plot(median_sma2, median_mu2+ np.log10(0.7 ** 2.0), linewidth=7.0, c=u'#1f77b4', alpha=1, label='Quick', zorder=5)
ax3.plot(median_sma3, median_mu3+ np.log10(0.7 ** 2.0), linewidth=7.0, c=u'#1f77b4', alpha=1, label='Quick', zorder=5)


print ngals1, ngals2, ngals3


##############
#Highres
#############
#mass range 1
tng_isos1=[]
ngals1=0

#mass range 2
tng_isos2=[]
ngals2=0

#mass range 3
tng_isos3=[]
ngals3=0
for mass, iso in zip(cat_masses, tng_isos_highres): 
    
    if (mass<mass_bins[0]) or (mass>mass_bins[-1]):
        continue

    elif (mass>=mass_bins[0]) and (mass<mass_bins[1]):
        ngals1+=1

        tng_isos1.append(iso)

        ax1.plot((iso['sma_kpc']) ** 0.25,
             np.log10(iso['intens_kpc'])+ np.log10(0.7 ** 2.0) , linewidth=0.5, c='r', alpha=0.2, 
                 label='_nolegend_', zorder=1)
                 #label='tng Galaxy '+str(i)+': $M_{\star} = $'+str(round(m_star,1)))
            
        
    elif (mass>=mass_bins[1]) and (mass<mass_bins[2]):
        ngals2+=1
        
        tng_isos2.append(iso)

        ax2.plot((iso['sma_kpc']) ** 0.25,
             np.log10(iso['intens_kpc'] )+ np.log10(0.7 ** 2.0), linewidth=0.5, c='r', alpha=0.4, 
                 label='_nolegend_')
                 #label='tng Galaxy '+str(i)+': $M_{\star} = $'+str(round(m_star,1)))
    
    elif (mass>=mass_bins[2]) and (mass<mass_bins[3]) :
        if (np.interp(6, iso['sma_kpc'], np.log10(iso['intens_kpc'])+ np.log10(0.7 ** 2.0)) > 8):#remove mergers:
            ngals3+=1

            tng_isos3.append(iso)

            ax3.plot((iso['sma_kpc']) ** 0.25,
                 np.log10(iso['intens_kpc'])+ np.log10(0.7 ** 2.0), linewidth=0.5, c='r', alpha=0.6, 
                     label='_nolegend_')
                     #label='tng Galaxy '+str(i)+': $M_{\star} = $'+str(round(m_star,1)))


        
## median profiles for tng
median_sma1, median_mu1 = get_median_profile(tng_isos1, pixel_scale = 0, quantity='intens_kpc')
median_sma2, median_mu2 = get_median_profile(tng_isos2, pixel_scale = 0, quantity='intens_kpc')
median_sma3, median_mu3 = get_median_profile(tng_isos3, pixel_scale = 0, quantity='intens_kpc')

ax1.plot(median_sma1, median_mu1+ np.log10(0.7 ** 2.0), linewidth=7.0, c='r', alpha=1, label='Highres', zorder=5)
ax2.plot(median_sma2, median_mu2+ np.log10(0.7 ** 2.0), linewidth=7.0, c='r', alpha=1, label='Highres', zorder=5)
ax3.plot(median_sma3, median_mu3+ np.log10(0.7 ** 2.0), linewidth=7.0, c='r', alpha=1, label='Highres', zorder=5)


print ngals1, ngals2, ngals3

                 
######################################################################################################################
# plot details
######################################################################################################################
# # X-Y limits
ax1.set_xlim(0.9, 4.5)
ax1.set_ylim(4, 10)
ax2.set_xlim(0.9, 4.5)
ax2.set_ylim(4, 10)
ax3.set_xlim(0.9, 4.5)
ax3.set_ylim(4, 10)

# Labels
# ax1.set_xlabel(r'$\log\ (M_{\star}/M_{\odot})$', 
#                size=60)
# ax1.set_ylabel(r'$\mathrm{d}N/\mathrm{d}\log M_{\star}\ [{\mathrm{Mpc}^{-3}}{\mathrm{dex}^{-1}}]$', 
#                size=60)
ax1.tick_params(axis='both', which='major', labelsize=30)
ax2.tick_params(axis='x', which='major', labelsize=30)
ax3.tick_params(axis='both', which='major', labelsize=30)

# #ax1.text(11.8, -3.7, r'$\mathrm{Normalized}$', size=60)
# ax1.axvline(11.6, linestyle='--', linewidth=4.0, alpha=0.8, zorder=0)

#text label
ax1.text(1.65, 4.2, str(mass_bins[0]) + '$< M_{cat} <$' + str(round(mass_bins[1],2)), size=30)
ax2.text(1.65, 4.2, str(round(mass_bins[1],2)) + '$< M_{cat} <$' + str(round(mass_bins[2],2)), size=30)
ax3.text(1.65, 4.2, str(round(mass_bins[2],2)) + '$< M_{cat} <$' + str(mass_bins[3]), size=30)

ax1.legend(fontsize=20)

#add twin x axis in kpc
x1, x2 = ax1.get_xlim()
ax1_twin = ax1.twiny()
ax1_twin.set_xlim(x1, x2)
ax1_twin.figure.canvas.draw()
ax1_twin.xaxis.set_ticks([2**0.25, 5**0.25, 10**0.25, 50**0.25, 100**0.25, 200**0.25, 300**0.25])
ax1_twin.xaxis.set_ticklabels([2, 5, 10, 50, 100, 200, 300])
ax1_twin.tick_params(axis='both', which='major', labelsize=15)
ax1_twin.set_xlabel(r'$R \: [kpc]$', fontsize=25)

x1, x2 = ax2.get_xlim()
ax2_twin = ax2.twiny()
ax2_twin.set_xlim(x1, x2)
ax2_twin.figure.canvas.draw()
ax2_twin.xaxis.set_ticks([2**0.25, 5**0.25, 10**0.25, 50**0.25, 100**0.25, 200**0.25, 300**0.25])
ax2_twin.xaxis.set_ticklabels([2, 5, 10, 50, 100, 200, 300])
ax2_twin.tick_params(axis='both', which='major', labelsize=15)
ax2_twin.set_xlabel(r'$R \: [kpc]$', fontsize=25)

x1, x2 = ax3.get_xlim()
ax3_twin = ax3.twiny()
ax3_twin.set_xlim(x1, x2)
ax3_twin.figure.canvas.draw()
ax3_twin.xaxis.set_ticks([2**0.25, 5**0.25, 10**0.25, 50**0.25, 100**0.25, 200**0.25, 300**0.25])
ax3_twin.xaxis.set_ticklabels([2, 5, 10, 50, 100, 200, 300])
ax3_twin.tick_params(axis='both', which='major', labelsize=15)
ax3_twin.set_xlabel(r'$R \: [kpc]$', fontsize=25)


######################################################################################################################

#axis labels and vertical lines
ax1.set_xlabel(r'$R^{1/4} \: [kpc^{1/4}]$', fontsize=30)
ax2.set_xlabel(r'$R^{1/4} \: [kpc^{1/4}]$', fontsize=30)
ax3.set_xlabel(r'$R^{1/4} \: [kpc^{1/4}]$', fontsize=30)
#ax3.set_ylabel(r'$M_{\star}( < r ) \: [ \log (M_{\odot})]$', fontsize=30)
ax1.set_ylabel(r'$\mu_{\star}\ [\log (M_{\odot})/\mathrm{kpc}^2]$', fontsize=30)
ax1.axvline(100.0 ** 0.25, linestyle='--', linewidth=3.0, alpha=0.6)
ax1.axvline(6.0 ** 0.25, linestyle='-', linewidth=3.0, alpha=0.6, c='grey', zorder=1)
ax2.axvline(100.0 ** 0.25, linestyle='--', linewidth=3.0, alpha=0.6)
ax2.axvline(6.0 ** 0.25, linestyle='-', linewidth=3.0, alpha=0.6, c='grey', zorder=1)
ax3.axvline(100.0 ** 0.25, linestyle='--', linewidth=3.0, alpha=0.6)
ax3.axvline(6.0 ** 0.25, linestyle='-', linewidth=3.0, alpha=0.6, c='grey', zorder=1)

######################################################################################################################
#grey out psf region
ax1.axvspan(0, 6**0.25, alpha=0.25, color='grey')
ax2.axvspan(0, 6**0.25, alpha=0.25, color='grey')
ax3.axvspan(0, 6**0.25, alpha=0.25, color='grey')
######################################################################################################################
#adjustments to ticks and space between subplots

#plt.setp([a.get_yticklabels() for a in fig.axes[1:]], visible=False)
plt.setp(ax2.get_yticklabels(), visible=False)
plt.setp(ax3.get_yticklabels(), visible=False)
#plt.setp(ax2.get_xticklabels()[0], visible=False)

#remove last label in x-axis of ax1 to prevent overlaping of labels with ax2
labels1 = [item.get_text() for item in ax2.get_xticklabels()[:-1]]
ax1.set_xticklabels(labels1)

#add a bit of space between subplots
# plt.tight_layout()

# fig.savefig('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Plots/profiles_matched_by_halo_mass_TNG.pdf',
#             dpi=100, format='pdf', bbox_inches='tight')

plt.show()
# Out:
# /Users/fardila/anaconda/envs/hsc_hydro/lib/python2.7/site-packages/ipykernel_launcher.py:68: RuntimeWarning: divide by zero encountered in log10
# /Users/fardila/anaconda/envs/hsc_hydro/lib/python2.7/site-packages/ipykernel_launcher.py:57: RuntimeWarning: divide by zero encountered in log10
# /Users/fardila/Documents/GitHub/HSC_vs_hydro/functions.py:96: RuntimeWarning: divide by zero encountered in log10
#   for gal in isos]), axis=0)
# 188 39 8
# /Users/fardila/anaconda/envs/hsc_hydro/lib/python2.7/site-packages/numpy/lib/function_base.py:3250: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# 188 39 8
