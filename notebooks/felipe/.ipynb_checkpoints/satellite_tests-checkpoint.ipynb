# %% [markdown]
# # Testing the effect of satellites on mass determination

# %% [markdown]
# How about just the mean (bias if non zero) and dispersion for M100? So you would want to study the distribution of M100_without - M100_with. Is the mean zero? And what is the width of the distirbution?

# %%
import sys
sys.path.append('/Users/fardila/Documents/GitHub/HSC_vs_hydro/')
from functions import *

import numpy as np
import os
import pickle

# %matplotlib inline 
# %load_ext autoreload 
# %autoreload 2
# Out:
# Created TAP+ (v1.0) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: False
# 	Port: 80
# 	SSL Port: 443
#
#
#       +------------------------------------------------------------+
#       |             Space Telescope Tables Package                 |
#       |                  TABLES Version 3.17                       |
#       |                                                            |
#       |   Space Telescope Science Institute, Baltimore, Maryland   |
#       |   Copyright (C) 2014 Association of Universities for       |
#       |            Research in Astronomy, Inc.(AURA)               |
#       |       See stsdas$copyright.stsdas for terms of use.        |
#       |         For help, send e-mail to help@stsci.edu            |
#       +------------------------------------------------------------+
# tables/:
#  fitsio/        tbplot/         tobsolete/      ttools/
#
#
#       +------------------------------------------------------------+
#       |       Space Telescope Science Data Analysis System         |
#       |                   STSDAS Version 3.17                      |
#       |                                                            |
#       |   Space Telescope Science Institute, Baltimore, Maryland   |
#       |   Copyright (C) 2014 Association of Universities for       |
#       |            Research in Astronomy, Inc.(AURA)               |
#       |       See stsdas$copyright.stsdas for terms of use.        |
#       |         For help, send e-mail to help@stsci.edu            |
#       |                                                            |
#       +------------------------------------------------------------+
# stsdas/:
#  analysis/      examples        hst_calib/      sobsolete/
#  contrib/       fitsio/         playpen/        toolbox/
#  describe       graphics/       problems
# isophote/:
#  bmodel         geompar@        isomap          magpar@
#  controlpar@    isoexam         isopall         samplepar@
#  ellipse        isoimap         isoplot

# %%
Illustris_file = '/Users/fardila/Documents/GitHub/HSC_vs_hydro/Data/Illustris/galaxies_orig_11.2.hdf5'

# %%
def get_masses_cen_sat(sim_file, sim_name, gal_n=0):

    # Load general simulation and galaxy properties
    f = h5py.File(sim_file, 'r')
    cat_sh_mstar = np.array(f['cat_sh_mstar'])

    try:
        map_stars = np.array(f['map_stars'])
    except:
        map_stars_insitu = np.array(f['map_stars_insitu'])
        map_stars_exsitu = np.array(f['map_stars_exsitu'])
        map_stars = map_stars_exsitu + map_stars_insitu

    map_size = f.attrs['stellar_map_size']
    n_pixels = f.attrs['stellar_map_np']

    pixel_scale=2 * (map_size/n_pixels)
    f.close()

    #make maps
    img_cen = map_stars[gal_n, 0, 1] * (pixel_scale ** 2) # Central
    img_sat = map_stars[gal_n, 1, 1] * (pixel_scale ** 2) # Satellites
    img_icl = map_stars[gal_n, 2, 1] * (pixel_scale ** 2) # Diffuse
    img_cen_sat = (img_cen + img_sat)           # Central + Satellites
    img_cen_icl = (img_cen + img_icl)           # Central + Satellites
    img_all = (img_cen + img_sat + img_icl)           # Central + Satellites + Diffuse

    #convert the image into unit of stellar mass instead of mass density
    m_cat = np.log10(cat_sh_mstar[gal_n])
    m_post = np.log10(np.sum(img_cen))
    m_post_icl = np.log10(np.sum(img_cen_icl))

    #ouput maps
    maps_location='/Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/'
    file_name=sim_name+'_'+str(gal_n)+'_xy'
    fits_prefix = maps_location + file_name
    save_to_fits(img_cen, fits_prefix + '_cen.fits')
    save_to_fits(img_cen_sat, fits_prefix + '_cen_sat.fits')
    save_to_fits(img_cen_icl, fits_prefix + '_cen_icl.fits')
    save_to_fits(img_all, fits_prefix + '_all.fits')

    data_cen=img_cen
    suffix_cen='_cen'
    
    data_cen_sat=img_cen_sat
    suffix_cen_sat='_cen_sat'


    masses_cen = get_mass_per_map(data_cen, suffix_cen, pixel_scale, file_name)
    masses_cen_sat = get_mass_per_map(data_cen_sat, suffix_cen_sat, pixel_scale,file_name)
    

    return m_cat, masses_cen, masses_cen_sat


def get_mass_per_map(data, suffix, pixel_scale, file_name):
    maps_location='/Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/'
    ###########################################################################
    #get background
    bkg = sep.Background(data, bw=10, bh=10, fw=5, fh=5)
    bkg_subtraced_data = data - bkg

    thresh = 500 * bkg.globalrms
    objects = sep.extract(bkg_subtraced_data, thresh, minarea = 100,
                          deblend_nthresh=24, deblend_cont=0.1)

    #find object closest to image center
    obj = find_closest(objects)

    #ellipse parameters
    theta = obj['theta']
    q = obj['b']/ obj['a']

    a_10, a_30, a_100 = (10. / pixel_scale), (30. / pixel_scale), (100. / pixel_scale)
    b_10, b_30, b_100 =  a_10 * q, a_30 * q, a_100 * q



    # plot background-subtracted image
    m, s = np.mean(data), np.std(data)
    fig, ax = plt.subplots()
    im = ax.imshow(data, interpolation='nearest', cmap=plt.get_cmap('viridis'),
                   vmin=m-s, vmax=m+s, origin='lower')

    # plot an ellipse for each object
    e_30 = Ellipse(xy=(obj['x'], obj['y']),
                 width=a_30,
                 height=b_30,
                 angle=theta * 180. / np.pi)
    e_30.set_facecolor('none')
    e_30.set_edgecolor('red')
    ax.add_artist(e_30)

    e_100 = Ellipse(xy=(obj['x'], obj['y']),
                 width=a_100,
                 height=b_100,
                 angle=theta * 180. / np.pi)
    e_100.set_facecolor('none')
    e_100.set_edgecolor('red')
    ax.add_artist(e_100)


    plt.savefig('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/ellipses/'+file_name)
    plt.clf()

    ###########################################################################
    #2D masses
    flux_10, fluxerr_10, flag_10 = sep.sum_ellipse(data, 100., 100.,
                                                   a_10, b_10, theta)
    flux_30, fluxerr_30, flag_30 = sep.sum_ellipse(data, 100., 100.,
                                                   a_30, b_30, theta)
    flux_100, fluxerr_100, flag_100 = sep.sum_ellipse(data, 100., 100.,
                                                      a_100, b_100, theta)

    ###########################################################################
    #1D masses from galSBP
    try:
        iso, iso_bin = galSBP.galSBP(maps_location+file_name+suffix+'.fits',
                                         galX=100.,
                                         galY=100.,
                                         galQ=q,
                                         galPA=theta* 180. / np.pi,
                                         maxSma=250,
                                         iniSma=50.0,
                                         stage=3,
                                         intMode='median',
                                         ellipStep=0.05,
                                         pix=pixel_scale,
                                         zpPhoto=0.0,
                                         isophote=x_isophote,
                                         xttools=x_ttools,
                                         recenter=True,
                                         savePng=False,
                                         verbose=True)


        ###########################################################################
        iso['sma_kpc'] = iso['sma'] * pixel_scale
        iso['intens_kpc']=iso['intens'] / (pixel_scale**2)

        m_1d_10, m_1d_30, m_1d_100 = oneD_mass(iso, 10.), \
                                    oneD_mass(iso, 30.), \
                                    oneD_mass(iso, 100.)

        #integrated mass from extrapolation
        extrap_mass = extrapolated_1D_mass(iso, 500)

    except:
        iso,m_1d_10, m_1d_30, m_1d_100, extrap_mass  = -99.99, -99.99, -99.99, -99.99, -99.99


    m_2d_10, m_2d_30, m_2d_100 = np.log10(flux_10), \
                                np.log10(flux_30), \
                                np.log10(flux_100)

    
    masses = [m_1d_10, m_1d_30, m_1d_100, m_2d_10,
            m_2d_30, m_2d_100, extrap_mass]
    
    return masses

# %% [markdown]
# ## Get masses for galaxies

# %%
illustris_masses_cat=[]
illustris_masses_cen=[]
illustris_masses_cen_sat=[]

#for i in range(10):
for i in range(339):
    
    print('^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^')
    print('^^^^^^^^GALAXY '+str(i)+'^^^^^^^^^^^^^^')
    print('^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^')

    try:
        m_cat, masses_cen, masses_cen_sat = get_masses_cen_sat(Illustris_file,'Illustris',gal_n=i)
        
    except ValueError:
        masses_cen=-99.99*np.ones(7)
        masses_cen_sat=-99.99*np.ones(7)
        m_cat=-99.99


    illustris_masses_cat.append(m_cat)
    illustris_masses_cen.append(masses_cen)
    illustris_masses_cen_sat.append(masses_cen_sat)
# Out:
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 0^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_0_xy_cen.fits
# ###      Input Image   : temp_IOTR5.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_0_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  15547175.0
# ###     Current outer background :  15547175.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_0_xy_cen_sat.fits
# ###      Input Image   : temp_DBPM9.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_0_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  24985785.0
# ###     Current outer background :  24985785.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 1^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_1_xy_cen.fits
# ###      Input Image   : temp_PGL6R.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_1_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  12708378.0
# ###     Current outer background :  12708378.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_1_xy_cen_sat.fits
# ###      Input Image   : temp_ZVHTI.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_1_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  25020820.0
# ###     Current outer background :  25020820.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 2^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_2_xy_cen.fits
# ###      Input Image   : temp_LWSFI.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_2_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  9256251.0
# ###     Current outer background :  9256251.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_2_xy_cen_sat.fits
# ###      Input Image   : temp_2CKUX.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_2_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  18301702.0
# ###     Current outer background :  18301702.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 3^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_3_xy_cen.fits
# ###      Input Image   : temp_13RUP.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_3_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  6824218.0
# ###     Current outer background :  6824218.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_3_xy_cen_sat.fits
# ###      Input Image   : temp_V434B.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_3_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  9476959.5
# ###     Current outer background :  9476959.5
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 4^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_4_xy_cen.fits
# ###      Input Image   : temp_N07ZS.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_4_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  2945663.0
# ###     Current outer background :  2945663.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_4_xy_cen_sat.fits
# ###      Input Image   : temp_1SQ6X.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_4_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  4596456.0
# ###     Current outer background :  4596456.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 5^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_5_xy_cen.fits
# ###      Input Image   : temp_NWNKT.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_5_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  3282265.0
# ###     Current outer background :  3282265.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_5_xy_cen_sat.fits
# ###      Input Image   : temp_WNOAI.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_5_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  7496094.0
# ###     Current outer background :  7496094.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 6^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_6_xy_cen.fits
# ###      Input Image   : temp_JROL7.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_6_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  34057960.0
# ###     Current outer background :  34057960.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_6_xy_cen_sat.fits
# ###      Input Image   : temp_4CDEC.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_6_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  5135854.0
# ###     Current outer background :  5135854.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 7^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_7_xy_cen.fits
# ###      Input Image   : temp_FDZE5.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_7_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  4503628.0
# ###     Current outer background :  4503628.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_7_xy_cen_sat.fits
# ###      Input Image   : temp_P4OZ4.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_7_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  12829788.0
# ###     Current outer background :  12829788.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 8^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_8_xy_cen.fits
# ###      Input Image   : temp_DTKQ1.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_8_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  3553512.0
# ###     Current outer background :  3553512.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_8_xy_cen_sat.fits
# ###      Input Image   : temp_W4XNI.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_8_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  5438499.0
# ###     Current outer background :  5438499.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 9^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_9_xy_cen.fits
# ###      Input Image   : temp_IE74C.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_9_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ###  ELLIPSE RUN FAILED IN ATTEMPT:  0
# ###  Error Information :  XXX Can not find the outBin: /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_9_xy_cen_ellip_3.bin!
# ###  !!! Make the Ellipse Run A Little Bit Easier !
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ----------------------------------------------------------------------------------------------------
# ###  Maxsma  250.0 -->  225.0
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  2
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_9_xy_cen.fits
# ###      Input Image   : temp_IE74C.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_9_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ###  ELLIPSE RUN FAILED IN ATTEMPT:  1
# ###  Error Information :  XXX Can not find the outBin: /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_9_xy_cen_ellip_3.bin!
# ###  !!! Make the Ellipse Run A Little Bit Easier !
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ----------------------------------------------------------------------------------------------------
# ###  Maxsma  225.0 -->  202.5
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  3
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_9_xy_cen.fits
# ###      Input Image   : temp_IE74C.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_9_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ###  ELLIPSE RUN FAILED IN ATTEMPT:  2
# ###  Error Information :  XXX Can not find the outBin: /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_9_xy_cen_ellip_3.bin!
# ###  !!! Make the Ellipse Run A Little Bit Easier !
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ----------------------------------------------------------------------------------------------------
# ###  Maxsma  202.5 -->  182.2
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  4
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_9_xy_cen.fits
# ###      Input Image   : temp_IE74C.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_9_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  3077454.5
# ###     Current outer background :  3077454.5
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_9_xy_cen_sat.fits
# ###      Input Image   : temp_BGTPD.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_9_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  4129532.0
# ###     Current outer background :  4129532.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 10^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# /Users/fardila/anaconda/envs/hsc_hydro/lib/python2.7/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_10_xy_cen.fits
# ###      Input Image   : temp_IN66T.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_10_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  8402219.0
# ###     Current outer background :  8402219.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_10_xy_cen_sat.fits
# ###      Input Image   : temp_84SGL.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_10_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  11390547.0
# ###     Current outer background :  11390547.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 11^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_11_xy_cen.fits
# ###      Input Image   : temp_Z2UMN.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_11_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  1576574.0
# ###     Current outer background :  1576574.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_11_xy_cen_sat.fits
# ###      Input Image   : temp_IRU2E.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_11_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  3956802.0
# ###     Current outer background :  3956802.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 12^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_12_xy_cen.fits
# ###      Input Image   : temp_LCNEB.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_12_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  1394119.0
# ###     Current outer background :  1394119.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_12_xy_cen_sat.fits
# ###      Input Image   : temp_MTL9F.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_12_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  8275020.0
# ###     Current outer background :  8275020.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 13^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_13_xy_cen.fits
# ###      Input Image   : temp_H3ARN.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_13_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  2549699.0
# ###     Current outer background :  2549699.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_13_xy_cen_sat.fits
# ###      Input Image   : temp_ZE8CE.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_13_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  3231041.0
# ###     Current outer background :  3231041.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 14^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_14_xy_cen.fits
# ###      Input Image   : temp_7M6WH.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_14_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  2538135.0
# ###     Current outer background :  2538135.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ...
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_333_xy_cen_sat.fits
# ###      Input Image   : temp_GZAFA.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_333_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  0.0
# ###     Current outer background :  0.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 334^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_334_xy_cen.fits
# ###      Input Image   : temp_MHBQD.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_334_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  0.00394141755
# ###     Current outer background :  0.00394141755
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_334_xy_cen_sat.fits
# ###      Input Image   : temp_B1VWH.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_334_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  0.0
# ###     Current outer background :  0.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 335^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_335_xy_cen.fits
# ###      Input Image   : temp_17LN7.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_335_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  0.0
# ###     Current outer background :  0.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_335_xy_cen_sat.fits
# ###      Input Image   : temp_8Z1X4.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_335_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  0.0
# ###     Current outer background :  0.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 336^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_336_xy_cen.fits
# ###      Input Image   : temp_BZK2V.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_336_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  0.0
# ###     Current outer background :  0.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_336_xy_cen_sat.fits
# ###      Input Image   : temp_W81RZ.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_336_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  0.0
# ###     Current outer background :  0.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 337^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_337_xy_cen.fits
# ###      Input Image   : temp_3PBA2.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_337_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  0.0
# ###     Current outer background :  0.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_337_xy_cen_sat.fits
# ###      Input Image   : temp_DON7U.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_337_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  0.0
# ###     Current outer background :  0.0
# ----------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^GALAXY 338^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_338_xy_cen.fits
# ###      Input Image   : temp_6MFMN.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_338_xy_cen_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  0.0
# ###     Current outer background :  0.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###      galX, galY :  100.0 100.0
# ###      galR :  20.0
# ###      iniSma, maxSma :  50.0 250
# ###      Stage :  3
# ###      Step :  0.05
# ----------------------------------------------------------------------------------------------------
# ##       Set up the Ellipse configuration
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ##       Start the Ellipse Run: Attempt  1
# ----------------------------------------------------------------------------------------------------
# ###      Origin Image  : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_338_xy_cen_sat.fits
# ###      Input Image   : temp_3MW3O.fits
# ###      Output Binary : /Users/fardila/Documents/GitHub/HSC_vs_hydro/Figures/fits_files/Illustris_338_xy_cen_sat_ellip_3.bin
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ###     Input background value   :  0.0
# ###     1-D SBP background value :  0.0
# ###     Current outer background :  0.0
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### save as pickels

# %%
#save as pickles
pkl_masses_cen = open('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Data/Illustris/Illustris_masses_cen.pkl','wb')
pickle.dump(illustris_masses_cen,pkl_masses_cen)
pkl_masses_cen.close()

pkl_masses_cen_sat = open('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Data/Illustris/Illustris_masses_cen_sat.pkl','wb')
pickle.dump(illustris_masses_cen_sat, pkl_masses_cen_sat)
pkl_masses_cen_sat.close()

# %% [markdown]
# ## Compare M_100

# %%
M_100_cen = np.array([g[2] for g in illustris_masses_cen])
M_100_cen_sat = np.array([g[2] for g in illustris_masses_cen_sat])
cen_sat_diff = M_100_cen_sat - M_100_cen
cen_sat_diff = cen_sat_diff[cen_sat_diff<50]

# %%
plt.hist(cen_sat_diff, bins=30,
         label= r'mean = '+str(round(np.nanmean(cen_sat_diff),3))+'$\pm$'+str(round(np.nanstd(cen_sat_diff),3)))
plt.xlabel(r'$M_{\mathrm{cen, sat}}^{100} - M_{\mathrm{cen}}^{100}$', fontsize=20)
plt.ylabel('Count', fontsize=20)
plt.legend(fontsize=15)
